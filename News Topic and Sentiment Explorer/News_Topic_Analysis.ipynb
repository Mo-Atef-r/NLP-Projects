# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset_path = r"D:\Data_and_AI\Datasets\News Category Dataset\News_Category_Dataset_v3.json"

#the file is in JSON Line format, so we set lines=True
df = pd.read_json(dataset_path, lines=True)
df.head()
# Out:
#                                                 link  \
# 0  https://www.huffpost.com/entry/covid-boosters-...
# 1  https://www.huffpost.com/entry/american-airlin...
# 2  https://www.huffpost.com/entry/funniest-tweets...
# 3  https://www.huffpost.com/entry/funniest-parent...
# 4  https://www.huffpost.com/entry/amy-cooper-lose...
#
#                                             headline   category  \
# 0  Over 4 Million Americans Roll Up Sleeves For O...  U.S. NEWS
# 1  American Airlines Flyer Charged, Banned For Li...  U.S. NEWS
# 2  23 Of The Funniest Tweets About Cats And Dogs ...     COMEDY
# 3  The Funniest Tweets From Parents This Week (Se...  PARENTING
# 4  Woman Who Called Cops On Black Bird-Watcher Lo...  U.S. NEWS
#
#                                    short_description               authors  \
# 0  Health experts said it is too early to predict...  Carla K. Johnson, AP
# 1  He was subdued by passengers and crew when he ...        Mary Papenfuss
# 2  "Until you have a dog you don't understand wha...         Elyse Wanshel
# 3  "Accidentally put grown-up toothpaste on my to...      Caroline Bologna
# 4  Amy Cooper accused investment firm Franklin Te...        Nina Golgowski
#
#         date
# 0 2022-09-23
# 1 2022-09-23
# 2 2022-09-23
# 3 2022-09-23
# 4 2022-09-22

# %%
df.shape
# Out:
# (209527, 6)

# %%
print(df.category.value_counts())
# Out:
# category
# POLITICS          35602
# WELLNESS          17945
# ENTERTAINMENT     17362
# TRAVEL             9900
# STYLE & BEAUTY     9814
# PARENTING          8791
# HEALTHY LIVING     6694
# QUEER VOICES       6347
# FOOD & DRINK       6340
# BUSINESS           5992
# COMEDY             5400
# SPORTS             5077
# BLACK VOICES       4583
# HOME & LIVING      4320
# PARENTS            3955
# THE WORLDPOST      3664
# WEDDINGS           3653
# WOMEN              3572
# CRIME              3562
# IMPACT             3484
# DIVORCE            3426
# WORLD NEWS         3299
# MEDIA              2944
# WEIRD NEWS         2777
# GREEN              2622
# WORLDPOST          2579
# RELIGION           2577
# STYLE              2254
# SCIENCE            2206
# TECH               2104
# TASTE              2096
# MONEY              1756
# ARTS               1509
# ENVIRONMENT        1444
# FIFTY              1401
# GOOD NEWS          1398
# U.S. NEWS          1377
# ARTS & CULTURE     1339
# COLLEGE            1144
# LATINO VOICES      1130
# CULTURE & ARTS     1074
# EDUCATION          1014
# Name: count, dtype: int64

# %%
#Dropping full-row duplicates
df=df.drop_duplicates()
df.shape
# Out:
# (209514, 6)

# %%
for column in df.columns:
    print(f"No. of duplicates in {column} column: {df[column].duplicated().sum()}")
# Out:
# No. of duplicates in link column: 28
# No. of duplicates in headline column: 1518
# No. of duplicates in category column: 209472
# No. of duplicates in short_description column: 22492
# No. of duplicates in authors column: 180345
# No. of duplicates in date column: 205624

# %% [markdown]
# __Duplicates in category, authors, and date columns are fine. Other columns must be addressed__

# %%
df[df.link.duplicated(keep=False)]
# Out:
#                                                      link  \
# 63573   https://www.huffingtonpost.comhttp://www.polit...
# 63586   https://www.huffingtonpost.comhttp://www.polit...
# 65188   https://www.huffingtonpost.comhttp://www.polit...
# 65202   https://www.huffingtonpost.comhttp://www.polit...
# 65759   https://www.huffingtonpost.comhttp://elections...
# 65801   https://www.huffingtonpost.comhttp://elections...
# 65907   https://www.huffingtonpost.comhttp://www.theat...
# 65989   https://www.huffingtonpost.comhttp://nymag.com...
# 65991   https://www.huffingtonpost.comhttp://nymag.com...
# 66841   https://www.huffingtonpost.comhttp://www.theat...
# 70059   https://www.huffingtonpost.comhttp://thinkprog...
# 70153   https://www.huffingtonpost.comhttp://thinkprog...
# 70505   https://www.huffingtonpost.comhttp://www.newyo...
# 70585   https://www.huffingtonpost.comhttp://www.newyo...
# 70662   https://www.huffingtonpost.comhttp://www.nytim...
# 70664   https://www.huffingtonpost.comhttps://www.publ...
# 70665   https://www.huffingtonpost.comhttp://nymag.com...
# 70669   https://www.huffingtonpost.comhttps://www.publ...
# 70670   https://www.huffingtonpost.comhttp://nymag.com...
# 70671   https://www.huffingtonpost.comhttp://www.nytim...
# 72065   https://www.huffingtonpost.comhttps://www.wash...
# 72173   https://www.huffingtonpost.comhttps://www.wash...
# 72663   https://www.huffingtonpost.comhttp://testkitch...
# 73084   https://www.huffingtonpost.comhttp://www.teenv...
# 73149   https://www.huffingtonpost.comhttp://www.teenv...
# 73974   https://www.huffingtonpost.comhttps://www.wash...
# 73986   https://www.huffingtonpost.comhttps://www.wash...
# 75119   https://www.huffingtonpost.comhttp://www.mothe...
# 75123   https://www.huffingtonpost.comhttp://www.mothe...
# 75820   https://www.huffingtonpost.comhttp://pubx.co/p...
# 75989   https://www.huffingtonpost.comhttp://pubx.co/p...
# 76183   https://www.huffingtonpost.comhttp://testkitch...
# 79028   https://www.huffingtonpost.comhttp://testkitch...
# 79863   https://www.huffingtonpost.comhttp://testkitch...
# 83185   https://www.huffingtonpost.comhttps://medium.c...
# 83215   https://www.huffingtonpost.comhttps://medium.c...
# 84444   https://www.huffingtonpost.comhttp://nymag.com...
# 84449   https://www.huffingtonpost.comhttp://nymag.com...
# 84890   https://www.huffingtonpost.comhttp://www.newre...
# 84965   https://www.huffingtonpost.comhttp://www.newre...
# 85537   https://www.huffingtonpost.comhttp://highline....
# 85570   https://www.huffingtonpost.comhttp://highline....
# 87539   https://www.huffingtonpost.comhttp://recode.ne...
# 87546   https://www.huffingtonpost.comhttp://recode.ne...
# 137333  https://www.huffingtonpost.comhttp://www.refin...
# 138302  https://www.huffingtonpost.comhttp://www.refin...
# 168020  https://www.huffingtonpost.comhttp://www.newre...
# 168238  https://www.huffingtonpost.comhttp://www.newre...
# 197728  https://www.huffingtonpost.comhttp://www.guilt...
# 197729  https://www.huffingtonpost.comhttp://www.guilt...
# 197916  https://www.huffingtonpost.comhttp://stylelike...
# 197921  https://www.huffingtonpost.comhttp://stylelike...
# 198680  https://www.huffingtonpost.comhttp://www.purpo...
# 202765  https://www.huffingtonpost.comhttp://www.purpo...
# 205709  https://www.huffingtonpost.comhttp://stylenews...
# 205720  https://www.huffingtonpost.comhttp://stylenews...
#
#                                                  headline        category  \
# 63573   Hardly anybody wants to speak at Trump's conve...        POLITICS
# 63586   Hardly anybody wants to speak at Trump's conve...        POLITICS
# 65188         Women For Trump – His Female Fans Speak Out        POLITICS
# 65202                    Women Supporting Trump Speak Out        POLITICS
# 65759   POLLS: Tight Race For Clinton And Sanders In C...        POLITICS
# 65801                            POLL: California Narrows        POLITICS
# 65907            The Fierceness Of ‘Femme, Fat And Asian’           WOMEN
# 65989                         Hillary Clinton vs. Herself           WOMEN
# 65991                         Hillary Clinton vs. Herself        POLITICS
# 66841           The Fierceness of ‘Femme, Fat, and Asian'    QUEER VOICES
# 70059   Hillary Clinton Just Released A Plan To Target...        POLITICS
# 70153   Hillary Clinton Just Released A Plan To Target...        POLITICS
# 70505        Trump's Convention Strategy: 'The Fix Is In'        POLITICS
# 70585        Trump’s Convention Strategy: 'The Fix Is In'        POLITICS
# 70662   GOP Donors, Eager To Defeat Donald Trump, Lear...        POLITICS
# 70664   How ‘Citizens United’ Is Helping Hillary Clint...        POLITICS
# 70665   The Sanders Campaign’s Sexist New Argument: Hi...        POLITICS
# 70669   How ‘Citizens United’ Is Helping Hillary Clint...        POLITICS
# 70670   The Sanders Campaign’s Sexist New Argument: Hi...           WOMEN
# 70671   G.O.P. Donors, Eager To Defeat Donald Trump, L...        POLITICS
# 72065   I Asked Trump A Policy Question. Then He Calle...           WOMEN
# 72173   I asked Trump a policy question. Then he calle...        POLITICS
# 72663             Hey America, Stop Being So Islamophobic        POLITICS
# 73084   Nancy Reagan's Disappointing Legacy On LGBTQ A...        POLITICS
# 73149   Former First Lady Nancy Reagan Watched Thousan...    QUEER VOICES
# 73974   The Republican Party’s implosion over Donald T...        POLITICS
# 73986   The GOP Implosion Over Donald Trump's Candidac...        POLITICS
# 75119   The Inside Story Of The Chinese Casino Money F...        POLITICS
# 75123                    MAG: Sheldon Adelson Bets It All        POLITICS
# 75820   Emaciated Mother Dog Digs Hole To Deliver Her ...           GREEN
# 75989   Emaciated Mother Dog Digs Hole To Deliver Her ...           GREEN
# 76183   Islamophobia In The U.S.: A Running List We Re...        POLITICS
# 79028                                        The Crossing   THE WORLDPOST
# 79863                                        The Crossing   THE WORLDPOST
# 83185                      On Gawker's Problem With Women           WOMEN
# 83215                      On Gawker’s Problem With Women           MEDIA
# 84444             Willie Nelson’s Crusade to Stop Big Pot        POLITICS
# 84449                           Willie Nelson vs. Big Pot        POLITICS
# 84890   The Plan To Save The World: What Success At Th...        POLITICS
# 84965                          The Plan To Save The World           GREEN
# 85537      The Life And Death Of An Amazon Warehouse Temp        POLITICS
# 85570      The Life and Death of an Amazon Warehouse Temp        BUSINESS
# 87539   REPORT: Twitter Plans To Go Beyond 140-Charact...            TECH
# 87546   Twitter Plans To Go Beyond Its 140-Character L...            TECH
# 137333                       Throw-On-And-Go Work Dresses  STYLE & BEAUTY
# 138302                        8 Dresses Every Woman Needs  STYLE & BEAUTY
# 168020       The Hell Of American Day Care | New Republic       PARENTING
# 168238                      The Hell Of American Day Care       PARENTING
# 197728                                 Fashion At The Met  STYLE & BEAUTY
# 197729     Fashion At The Met: From The Stylelist Network  STYLE & BEAUTY
# 197916  Graceful Dancer's Vintage Closet: From the Sty...  STYLE & BEAUTY
# 197921  Graceful Dancer's Vintage Closet: From The Sty...  STYLE & BEAUTY
# 198680           15 Things You Should Give Up To Be Happy        WELLNESS
# 202765           15 Things You Should Give Up To Be Happy        WELLNESS
# 205709     See Jessica Biel's Engagement Ring -- Finally!  STYLE & BEAUTY
# 205720     See Jessica Biel's Engagement Ring -- Finally!  STYLE & BEAUTY
#
#                                         short_description authors       date
# 63573   POLITICO reached out to more than 50 prominent...         2016-06-27
# 63586   A slot at the GOP convention used to be a care...         2016-06-27
# 65188   In March, days after Mitt Romney excoriated Do...         2016-06-09
# 65202   In March, days after Mitt Romney excoriated Do...         2016-06-09
# 65759   This chart combines the latest opinion polls o...         2016-06-03
# 65801   Polls and chart for 2016 California Democratic...         2016-06-02
# 65907   Few RuPaul’s Drag Race fans could have been su...         2016-06-01
# 65989   In a locker room at the University of Bridgepo...         2016-05-31
# 65991   In a locker room at the University of Bridgepo...         2016-05-31
# 66841   Few RuPaul’s Drag Race fans could have been su...         2016-05-21
# 70059   During a speech Wednesday at the National Acti...         2016-04-14
# 70153   During a speech Wednesday at the National Acti...         2016-04-13
# 70505   More than three months before any ballots have...         2016-04-09
# 70585   More than three months before any ballots have...         2016-04-08
# 70662   Nestled in the neo-Georgian sanctuary of the K...         2016-04-07
# 70664   Hillary Clinton fashions herself as the ultima...         2016-04-07
# 70665   On Tuesday night, following Bernie Sanders’s b...         2016-04-07
# 70669   Reforms wait as Democrat's allies target GOP w...         2016-04-07
# 70670   On Tuesday night, following Bernie Sanders’s b...         2016-04-07
# 70671   Nestled in the neo-Georgian sanctuary of the K...         2016-04-07
# 72065   Donald Trump, the Republican front-runner for ...         2016-03-22
# 72173   Donald Trump, the Republican front-runner for ...         2016-03-21
# 72663   Islamophobia is real. And it's not going anywh...         2016-03-15
# 73084   Nancy Reagan will be laid to rest this week af...         2016-03-10
# 73149   Nancy Reagan will be laid to rest this week af...         2016-03-10
# 73974   At a moment when Republicans had hoped to begi...         2016-02-29
# 73986   MADISON, Ala. — The implosion over Donald Trum...         2016-02-29
# 75119   It was around 10:30 p.m. when Steve Jacobs rol...         2016-02-16
# 75123   It was around 10:30 p.m. when Steve Jacobs rol...         2016-02-16
# 75820   Filthy, matted, emaciated and weak, with piece...         2016-02-08
# 75989   Filthy, matted, emaciated and weak, with piece...         2016-02-06
# 76183   After last year's terror attacks in Paris and ...         2016-02-04
# 79028   I came to Lesbos to listen and to learn. I wan...         2016-01-04
# 79863   An immersive reporting series hosted by Susan ...         2015-12-24
# 83185   On July 16, Gawker.com published a tabloid sto...         2015-11-16
# 83215   A former staff writer describes how a media co...         2015-11-16
# 84444   This begins to add up when you do the math. Ne...         2015-11-02
# 84449             Backstage at Farm Aid is a hidden city.         2015-11-02
# 84890   Right now, we're in a car, hanging on for dear...         2015-10-28
# 84965   Right now, we're in a car, hanging on for dear...         2015-10-28
# 85537   On Jan. 18, 2013, as the sun went down, Jeff L...         2015-10-21
# 85570   In 2013, an Amazon warehouse temp collapsed on...         2015-10-21
# 87539   Twitter is building a new product that will al...         2015-09-29
# 87546   Twitter is building a new product that will al...         2015-09-29
# 137333  It's tough enough prying ourselves from the wa...         2014-03-08
# 138302  From a perfect variation on the classic shirt ...         2014-02-26
# 168020  It was 5:30 in the morning when Kenya Mire loo...         2013-04-17
# 168238  Excellent day cares are available, of course, ...         2013-04-15
# 197728  From Guilty and Glamorous Courtesy Photo It's ...         2012-06-03
# 197729  From Guilty and Glamorous Courtesy Photo It's ...         2012-06-03
# 197916  I learned from Megan that in the world of ball...         2012-06-01
# 197921  I learned from Megan that in the world of ball...         2012-06-01
# 198680  Here is a list of 15 things which, if you give...         2012-05-24
# 202765  Here is a list of 15 things which, if you give...         2012-04-10
# 205709  We’ve been waiting -- and we must say, we’re v...         2012-03-09
# 205720  We've been waiting -- and we must say, we're v...         2012-03-09

# %% [markdown]
# __Link column duplicates have different short descriptions. We should keep the entries that have the longest one.__

# %%
indices = df.groupby("link")["short_description"].apply(lambda x: x.str.len().idxmax())
df = df.loc[indices].reset_index(drop=True)
df.shape
# Out:
# (209486, 6)

# %% [markdown]
# Dropped "link" column duplicates (28)

# %%
for column in df.columns:
    print(f"No. of duplicates in {column} column: {df[column].duplicated().sum()}")
# Out:
# No. of duplicates in link column: 0
# No. of duplicates in headline column: 1509
# No. of duplicates in category column: 209444
# No. of duplicates in short_description column: 22481
# No. of duplicates in authors column: 180317
# No. of duplicates in date column: 205596

# %%
df.duplicated(subset=['headline', 'short_description']).sum()
# Out:
# 472

# %%
df.drop_duplicates(subset=['headline', 'short_description'], inplace=True)

# %%
for column in df.columns:
    print(f"No. of duplicates in {column} column: {df[column].duplicated().sum()}")
# Out:
# No. of duplicates in link column: 0
# No. of duplicates in headline column: 1037
# No. of duplicates in category column: 208972
# No. of duplicates in short_description column: 22009
# No. of duplicates in authors column: 179849
# No. of duplicates in date column: 205124

# %%
for column_name in df.columns:
    # Count NaN values
    nan_count = df[column_name].isna().sum()

    # Count empty strings (after converting to string and stripping whitespace)
    empty_string_count = (df[column_name].astype(str).str.strip() == '').sum()

    # Total empty entries (NaN + empty strings)
    total_empty = nan_count + empty_string_count

    # Print results
    print(f"Column: {column_name}")
    print(f"NaN count: {nan_count}")
    print(f"Empty string count: {empty_string_count}")
    print(f"Total empty entries: {total_empty}\n\n")
# Out:
# Column: link
# NaN count: 0
# Empty string count: 0
# Total empty entries: 0
#
#
# Column: headline
# NaN count: 0
# Empty string count: 2
# Total empty entries: 2
#
#
# Column: category
# NaN count: 0
# Empty string count: 0
# Total empty entries: 0
#
#
# Column: short_description
# NaN count: 0
# Empty string count: 19611
# Total empty entries: 19611
#
#
# Column: authors
# NaN count: 0
# Empty string count: 37288
# Total empty entries: 37288
#
#
# Column: date
# NaN count: 0
# Empty string count: 0
# Total empty entries: 0

# %% [markdown]
# Drop Empty entries in the headline column (2 rows)

# %%
column_name = 'headline'
# Create a mask for non-empty entries
# Keep rows where value is not NaN and not an empty string (after stripping)
mask = ~(df[column_name].isna() | (df[column_name].astype(str).str.strip() == ''))

# Count entries to be dropped
entries_to_drop = len(df) - mask.sum()

# Drop rows where column has empty entries
df = df[mask].copy()

# %% [markdown]
# __Now we have duplicate headlines with different short descriptions, and duplicate short descriptions with different headlines, which is not a problem for what we're doing, as we've already made sure we have unique (headline, short description) pairs.__

# %% [markdown]
# ## Text Preprocessing

# %%
df['train_text'] = df['headline'].astype(str) + " " + df["short_description"].astype(str)
df.head()
# Out:
#                                                 link  \
# 0  https://www.huffingtonpost.com/entry/%C3%A9dga...
# 1  https://www.huffingtonpost.com/entry/-20-reaso...
# 2  https://www.huffingtonpost.com/entry/-2014-bet...
# 3  https://www.huffingtonpost.com/entry/-4-not-ou...
# 4  https://www.huffingtonpost.com/entry/-5-looks-...
#
#                                             headline       category  \
# 0  Édgar Ramírez Stands In Solidarity With Venezu...  LATINO VOICES
# 1      20 Reasons to Drop Everything and Go to Spain         TRAVEL
# 2                WATCH: 2014 BET Awards Performances   BLACK VOICES
# 3  #4 Not Our Finest Hour: Why Is Liberal America...       POLITICS
# 4    Flat Out Adorable: 5 Looks to Mimic This Season          STYLE
#
#                                    short_description  \
# 0  “The recall vote (revocatory referendum) is cl...
# 1  See more photos of natural parks in Spain 20.)...
# 2
# 3  In countless ways, the political force that ha...
# 4  Whether you're out exploring a new city or hea...
#
#                                              authors       date  \
# 0                               Tanisha Love Ramirez 2016-09-01
# 1  minube, Contributor\nCommunity of over 2 milli... 2014-01-15
# 2                                   Brennan Williams 2014-06-30
# 3  Andy Schmookler, ContributorAward-winning auth... 2014-09-30
# 4     Alisa Gould-Simon, ContributorCo-Founder, Pose 2014-06-19
#
#                                           train_text
# 0  Édgar Ramírez Stands In Solidarity With Venezu...
# 1  20 Reasons to Drop Everything and Go to Spain ...
# 2               WATCH: 2014 BET Awards Performances
# 3  #4 Not Our Finest Hour: Why Is Liberal America...
# 4  Flat Out Adorable: 5 Looks to Mimic This Seaso...

# %%
import re
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# %%
stop_words = set(stopwords.words('english'))
lem = WordNetLemmatizer()

def preprocess_and_tokenize(text):
    """
    Cleans text, tokenizes, removes stopwords and short tokens, and lemmatizes.
    Returns a list of tokens.
    """
    # Convert to string type to handle potential non-string entries
    text = str(text)
    # Remove non-alphabetic characters and convert to lowercase
    text = re.sub(r'[^a-z\s]', ' ', text.lower())

    # Tokenize the cleaned text
    tokens = word_tokenize(text)

    # Remove stopwords and very short tokens (length less than 3)
    tokens = [t for t in tokens if t not in stop_words and len(t) > 2]

    # Lemmatize the tokens to reduce words to their base form
    tokens = [lem.lemmatize(t) for t in tokens]

    return tokens # Returns a list of tokens, not a single string

# %%
df['train_text_tokens'] = df['train_text'].apply(preprocess_and_tokenize)
df.head()
# Out:
#                                                 link  \
# 0  https://www.huffingtonpost.com/entry/%C3%A9dga...
# 1  https://www.huffingtonpost.com/entry/-20-reaso...
# 2  https://www.huffingtonpost.com/entry/-2014-bet...
# 3  https://www.huffingtonpost.com/entry/-4-not-ou...
# 4  https://www.huffingtonpost.com/entry/-5-looks-...
#
#                                             headline       category  \
# 0  Édgar Ramírez Stands In Solidarity With Venezu...  LATINO VOICES
# 1      20 Reasons to Drop Everything and Go to Spain         TRAVEL
# 2                WATCH: 2014 BET Awards Performances   BLACK VOICES
# 3  #4 Not Our Finest Hour: Why Is Liberal America...       POLITICS
# 4    Flat Out Adorable: 5 Looks to Mimic This Season          STYLE
#
#                                    short_description  \
# 0  “The recall vote (revocatory referendum) is cl...
# 1  See more photos of natural parks in Spain 20.)...
# 2
# 3  In countless ways, the political force that ha...
# 4  Whether you're out exploring a new city or hea...
#
#                                              authors       date  \
# 0                               Tanisha Love Ramirez 2016-09-01
# 1  minube, Contributor\nCommunity of over 2 milli... 2014-01-15
# 2                                   Brennan Williams 2014-06-30
# 3  Andy Schmookler, ContributorAward-winning auth... 2014-09-30
# 4     Alisa Gould-Simon, ContributorCo-Founder, Pose 2014-06-19
#
#                                           train_text  \
# 0  Édgar Ramírez Stands In Solidarity With Venezu...
# 1  20 Reasons to Drop Everything and Go to Spain ...
# 2               WATCH: 2014 BET Awards Performances
# 3  #4 Not Our Finest Hour: Why Is Liberal America...
# 4  Flat Out Adorable: 5 Looks to Mimic This Seaso...
#
#                                    train_text_tokens
# 0  [dgar, ram, rez, stand, solidarity, venezuelan...
# 1  [reason, drop, everything, spain, see, photo, ...
# 2                   [watch, bet, award, performance]
# 3  [finest, hour, liberal, america, falling, far,...
# 4  [flat, adorable, look, mimic, season, whether,...

# %% [markdown]
# ## Topic Modeling

# %% [markdown]
# ### LDA: Latent Dirichlet Allocation

# %%
import gensim
from gensim import corpora
from gensim.models import LdaModel
from gensim.models.coherencemodel import CoherenceModel
from gensim.models.phrases import Phrases, Phraser

# %%
# Step 1: Build the Bigram model using the full dataset's tokenized text.
# The Phrases model learns frequent contiguous sequences of words across all documents.
# min_count: Ignore all phrases with total frequency lower than this.
# threshold: A measure to form phrases; higher value means fewer phrases are created.
bigram = Phrases(df['train_text_tokens'], min_count=5, threshold=100)
# Phraser creates an optimized model for faster transformation.
bigram_mod = Phraser(bigram)


# Step 2: Build the Trigram model on top of the Bigram model, using the full dataset.
# This allows for the detection of three-word phrases, like "new_york_city", from the entire corpus.
trigram = Phrases(bigram_mod[df['train_text_tokens']], min_count=5, threshold=100)
trigram_mod = Phraser(trigram)


# Step 3: Apply Bigram and Trigram transformation to all documents in the DataFrame.
# This iterates through each document's list of tokens and replaces individual words
# with detected multi-word phrases (e.g., 'new', 'york' -> 'new_york').
processed_df = [trigram_mod[bigram_mod[doc]] for doc in df['train_text_tokens']]

# %%
# Step 4: Create a Gensim Dictionary from all processed tokens with n-grams.
# This dictionary will map all unique n-grams (words, bigrams, trigrams) from your
# entire dataset to integer IDs. It is a crucial input for the LDA model.
dictionary = corpora.Dictionary(processed_df)

# Step 5: Filter out very rare or very common tokens based on statistics from the full dataset.
# This step helps to improve topic quality by removing noise (very rare words)
# and overly generic terms (very common words that don't differentiate topics).
# no_below: Minimum number of documents a token must appear in to be kept.
# no_above: Maximum proportion of documents a token can appear in to be kept (e.g., 0.5 means 50%).
# keep_n: Maximum number of tokens to keep in the dictionary (top N most frequent).
dictionary.filter_extremes(no_below=5, no_above=0.5, keep_n=100000)

# %%
# Step 6: Create a Gensim Corpus (Bag-of-Words representation) from all processed tokens.
# Each document in the entire dataset is converted into a list of (word_id, word_count) tuples,
# representing its frequency of occurrence for each unique token in the dictionary.
corpus = [dictionary.doc2bow(doc) for doc in processed_df]

print(f"Number of unique tokens in dictionary (after n-grams and filtering): {len(dictionary)}")
print(f"Number of documents in corpus: {len(corpus)}")
print(f"Example of first document in corpus (word_id, count): {corpus[0][:5]}")
# Out:
# Number of unique tokens in dictionary (after n-grams and filtering): 33806
# Number of documents in corpus: 209012
# Example of first document in corpus (word_id, count): [(0, 1), (1, 1), (2, 1), (3, 1), (4, 1)]

# %% [markdown]
# After trying different values for num_topics, 7 seems like a good compromise between coherence and interpretability

# %%
num_topics = 7 

# id2word: Provides the mapping from word IDs back to words for topic interpretation.
# passes: The number of training iterations. More passes can lead to better convergence.
# random_state: Ensures reproducibility of the results.
# chunksize: Determines how many documents are processed in each training chunk.
# alpha and eta: Dirichlet priors for topic-document and word-topic distributions.
#                'auto' allows the model to learn these parameters from the data.
# per_word_topics: Set to True to enable per-word topic distribution tracking.
lda_model = LdaModel(
    corpus=corpus,
    id2word=dictionary,
    num_topics=num_topics,
    random_state=42,
    passes=15,
    chunksize=2000,
    alpha='auto',
    eta='auto',
    per_word_topics=True
)

print("\nLDA Model Training Complete.")

# Inspect the Topics.
# Print the top 10 most probable words/n-grams for each learned topic.
print(f"\nTop {num_topics} Topics from LDA Model:")
for idx, topic in lda_model.print_topics(num_words=10):
    print(f"Topic {idx}: {topic}")

# Calculate Topic Coherence (c_v)
# C_V coherence measures the semantic similarity between high-scoring words in a topic
# and is considered a good indicator of human interpretability.

coherence_model_lda = CoherenceModel(
    model=lda_model,
    texts=processed_df, 
    dictionary=dictionary,
    coherence='c_v' 
)
coherence_lda = coherence_model_lda.get_coherence()
print(f"\nCoherence Score (C_V) for LDA model: {coherence_lda:.4f}")
# Out:
# LDA Model Training Complete.
#
# Top 7 Topics from LDA Model:
# Topic 0: 0.020*"make" + 0.020*"life" + 0.018*"way" + 0.016*"child" + 0.014*"need" + 0.014*"take" + 0.013*"kid" + 0.012*"work" + 0.011*"help" + 0.009*"school"
# Topic 1: 0.026*"day" + 0.020*"world" + 0.013*"home" + 0.012*"best" + 0.012*"wedding" + 0.010*"city" + 0.009*"top" + 0.008*"white_house" + 0.007*"around" + 0.006*"host"
# Topic 2: 0.015*"gop" + 0.014*"police" + 0.010*"claim" + 0.009*"killed" + 0.009*"dead" + 0.008*"california" + 0.008*"fire" + 0.008*"shooting" + 0.007*"florida" + 0.007*"administration"
# Topic 3: 0.018*"food" + 0.012*"vote" + 0.011*"medium" + 0.011*"ukraine" + 0.011*"russia" + 0.010*"russian" + 0.009*"protest" + 0.008*"lawmaker" + 0.008*"voter" + 0.008*"art"
# Topic 4: 0.019*"year" + 0.016*"one" + 0.016*"new" + 0.013*"woman" + 0.013*"people" + 0.013*"time" + 0.010*"get" + 0.010*"like" + 0.009*"first" + 0.007*"want"
# Topic 5: 0.031*"week" + 0.028*"show" + 0.025*"photo" + 0.020*"video" + 0.019*"look" + 0.017*"star" + 0.017*"black" + 0.012*"new_york" + 0.010*"watch" + 0.009*"actor"
# Topic 6: 0.055*"trump" + 0.021*"said" + 0.020*"say" + 0.018*"president" + 0.013*"donald" + 0.010*"state" + 0.009*"american" + 0.009*"republican" + 0.008*"former" + 0.007*"million"
#
# Coherence Score (C_V) for LDA model: 0.4001

# %% [markdown]
# Possible Interpretations:
# * Topic 0: __Family__ (life, child, kid, work, school)
# * Topic 1: __Travel / Lifestyle__ (white house, city, wedding, world, host)
# * Topic 2: __Crime / U.S. Local News__ (GOP, police, california, florida, killed, dead)
# * Topic 3: __Politics / World News__ ( Ukraine, Russia, protest, lawmaker, vote)
# * Topic 4: __General Interests__ (want, like, people, new)
# * Topic 5: __Entertainment / Media__ (actor, show, start, photo, video)
# * Topic 6: __Donald Trump / U.S. Republican Party__ (Donald, Trump, state, american, republican, president)

# %%
# Assign dominant topic to each document in the DataFrame
# Iterate through the corpus to get the topic distribution for each document.
# The dominant topic for each document is the one with the highest probability.
df_document_topics = []
for i, row in enumerate(lda_model[corpus]):
    # Each 'row' contains a list of (topic_id, probability) tuples for a document.
    # Sort these tuples in descending order by probability to find the dominant topic.
    row = sorted(row[0], key=lambda x: x[1], reverse=True)

    # Extract the dominant topic ID and its probability.
    # Handle cases where a document might not have any topic assigned (though rare with LDA).
    dominant_topic_id = row[0][0] if row else -1
    dominant_topic_prob = row[0][1] if row else 0.0

    # Store the results for the current document.
    df_document_topics.append({
        'dominant_topic': dominant_topic_id,
        'dominant_topic_prob': dominant_topic_prob,
        #'topic_distribution': row # keeping the full topic distribution for reference
    })

# Add the dominant topic information as new columns to the main DataFrame 'df'.
df['dominant_topic_id_lda'] = [d['dominant_topic'] for d in df_document_topics]
df['dominant_topic_prob_lda'] = [d['dominant_topic_prob'] for d in df_document_topics]

print("\nDominant LDA topics assigned to the DataFrame.")
print("First 5 rows with dominant topic and its probability:")
df[['headline', 'dominant_topic_id_lda', 'dominant_topic_prob_lda']].head()
# Out:
# Dominant LDA topics assigned to the DataFrame.
# First 5 rows with dominant topic and its probability:
#                                             headline  dominant_topic_id_lda  \
# 0  Édgar Ramírez Stands In Solidarity With Venezu...                      4
# 1      20 Reasons to Drop Everything and Go to Spain                      4
# 2                WATCH: 2014 BET Awards Performances                      4
# 3  #4 Not Our Finest Hour: Why Is Liberal America...                      4
# 4    Flat Out Adorable: 5 Looks to Mimic This Season                      1
#
#    dominant_topic_prob_lda
# 0                 0.340438
# 1                 0.315553
# 2                 0.318119
# 3                 0.279397
# 4                 0.263950

# %%
df.dominant_topic_prob_lda.describe()
# Out:
# count    209012.000000
# mean          0.336888
# std           0.069568
# min           0.165971
# 25%           0.285484
# 50%           0.326343
# 75%           0.377958
# max           0.718266
# Name: dominant_topic_prob_lda, dtype: float64

# %% [markdown]
# Saving the LDA Model

# %%
# Save LDA model
lda_model.save("Model\lda_model_gensim")

# Save dictionary (used to create BoW for new text)
dictionary.save("Model\lda_dictionary.dict")

# %% [markdown]
# ## Sentiment Analysis

# %%
df.to_csv("pre_sentiment_data_2.csv", index=False)
